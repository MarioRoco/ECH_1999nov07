# %%
eit_wavelength = 195 #171, 195, 284, or 304 [Angstrom]
eit_time = 'late' #'early' or 'late' (early: around 1 or 4 am; late: around 6 or 7 am)
idx_spectral_image = 120
line_label = 'NeVIII'

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import datetime as dt
from astropy.io import fits
import matplotlib.patches as patches
from scipy.odr import Model, RealData, ODR
from scipy.interpolate import interp1d
import matplotlib.lines as mlines
import sunpy.map
from astropy.coordinates import SkyCoord
from sunpy.coordinates import frames
import astropy.units as u
from matplotlib.path import Path
from scipy.optimize import curve_fit
from scipy.ndimage import gaussian_filter1d


import sys
import os
sys.path.append(os.path.abspath('..'))
from utils.data_path import path_data_soho 
from utils.SOHO_aux_functions import *
from utils.calibration_parameters__output import *
from utils.spectroheliogram_functions import *
from utils.solar_rotation_variables import *
from utils.aux_functions import *
from utils.general_variables import *
from utils.NeVIII_rest_wavelength import *

# %%
## Create a list with all the headers and another with all data arrays. Units of the data: W/sr/m^2/Angstrom
sumer_header_list, spectral_image_list, spectral_image_unc_list = SUMERraster_get_data_header_and_datauncertainties(sumer_filepath=path_data_soho+'sumer/', sumer_filename_list=filename_list, factor_fullspectrum=factor_fullspectrum, t_exp_sec=t_exp) 

# Chose one spectral image of the raster (index selected at the inputs)
spectral_image = spectral_image_list[idx_spectral_image]
spectral_image_unc = spectral_image_unc_list[idx_spectral_image]
header_sumer = sumer_header_list[idx_spectral_image]
# Out:
# WARNING: non-ASCII characters are present in the FITS file header and have been replaced by "?" characters [astropy.io.fits.util]

# %%
# Import EIT data

# Select the name of the EIT file according to the above inputs
if eit_time=='early':
    if eit_wavelength==171: 
        filename_eit = 'SOHO_EIT_171_19991107T010032_L1.fits'
        vmin_eit, vmax_eit = 3e1, 3e2
    elif eit_wavelength==195: 
        filename_eit = 'SOHO_EIT_195_19991107T042103_L1.fits'
        vmin_eit, vmax_eit = 4e1, 3e3
    elif eit_wavelength==284: 
        filename_eit = 'SOHO_EIT_284_19991107T011231_L1.fits'
        vmin_eit, vmax_eit = 4e1, 3e3
    elif eit_wavelength==304: 
        filename_eit = 'SOHO_EIT_304_19991107T013601_L1.fits'
        vmin_eit, vmax_eit = 4e1, 3e3

elif eit_time=='late':
    if eit_wavelength==171: 
        filename_eit = 'SOHO_EIT_171_19991107T070017_L1.fits'
        vmin_eit, vmax_eit = 3e1, 3e2
    elif eit_wavelength==195: 
        filename_eit = 'SOHO_EIT_195_19991107T063706_L1.fits'
        vmin_eit, vmax_eit = 4e1, 3e3
    elif eit_wavelength==284: 
        filename_eit = 'SOHO_EIT_284_19991107T070704_L1.fits'
        vmin_eit, vmax_eit = 4e1, 3e3
    elif eit_wavelength==304: 
        filename_eit = 'SOHO_EIT_304_19991107T073030_L1.fits'
        vmin_eit, vmax_eit = 4e1, 3e3

# Path of EIT file
filepath_eit = path_data_soho + 'eit/' + filename_eit

# Extract data and header
data_eit = fits.getdata(filepath_eit)[::-1]
header_eit = fits.getheader(filepath_eit)

# Creating a SunPy map object from an image
map_eit = sunpy.map.Map(filepath_eit)
map_eit
# Out:
# <sunpy.map.sources.soho.EITL1Map object at 0x754750db0e10>
# SunPy Map
# ---------
# Observatory:		 Solar and Heliospheric Observatory (SOHO)
# Instrument:		 Extreme-ultraviolet Imaging Telescope (EIT)
# Detector:		 EIT
# Measurement:		 195.0 Angstrom
# Wavelength:		 195.0 Angstrom
# Observation Date:	 1999-11-07 06:36:24
# Exposure Time:		 4.597 s
# Dimension:		 [512. 512.] pix
# Coordinate System:	 helioprojective
# Scale:			 [5.254 5.254] arcsec / pix
# Reference Pixel:	 [255.5 255.5] pix
# Reference Coord:	 [ 16.07367793 -12.22859187] arcsec
# array([[26.645298 , 25.10221  , 28.111696 , ..., 17.90905  , 17.805567 ,
#         17.341116 ],
#        [31.015905 , 28.902304 , 30.64002  , ..., 21.460566 , 21.078634 ,
#         18.440502 ],
#        [16.382088 , 16.066452 , 12.634296 , ...,  5.4581347,  7.216048 ,
#          4.517407 ],
#        ...,
#        [ 6.0468636,  6.9820905,  8.760125 , ..., 17.453205 , 12.98223  ,
#          9.579438 ],
#        [ 8.031419 ,  9.95644  , 10.432679 , ..., 18.190508 , 17.517155 ,
#          9.167297 ],
#        [ 7.0738487,  8.761258 ,  9.877385 , ..., 16.273819 , 14.521712 ,
#          8.610519 ]], shape=(512, 512), dtype='>f4')

# %%
# Load the intensity map and uncertainties
intensitymap_loaded_dic = np.load('../data/data_modified/intensity_map_'+line_label+'_interpolated.npz')
intensity_map = intensitymap_loaded_dic['intensity_map'] #2D-array
intensity_map_unc = intensitymap_loaded_dic['intensity_map_unc'] #2D-array
line_center_label = intensitymap_loaded_dic['line_center_label'] 
vmin_sumer, vmax_sumer = intensitymap_loaded_dic['vmin_vmax'] 

# Crop array in latitude 
intensity_map_croplat = intensity_map[slit_top_px:slit_bottom_px+1,:]
intensity_map_unc_croplat = intensity_map_unc[slit_top_px:slit_bottom_px+1,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Load the intensity map and uncertainties
# ----> 2 intensitymap_loaded_dic = np.load('../data/data_modified/intensity_map_'+line_label+'_interpolated.npz')
#       3 intensity_map = intensitymap_loaded_dic['intensity_map'] #2D-array
#       4 intensity_map_unc = intensitymap_loaded_dic['intensity_map_unc'] #2D-array
#
# NameError: name 'np' is not defined

# %%
from utils.solar_rotation_variables import *
closest_index = closest_index_EIT_SUMER_dic[filename_eit]
closest_time_sumer = closest_time_SUMER_to_EIT_dic[filename_eit]
time_eit = time_EIT_dic[filename_eit]
hour_eit = hour_EIT_dic[filename_eit]
HPlon_rotcomp = HPlon_rotcomp_dic[filename_eit]
HPlon
HPlat
HPlat_croplat = HPlat[slit_top_px:slit_bottom_px+1]


# HP latitude of the top and bottom limits of the SUMER spectra
HPlat_crop_top = HPlat[slit_top_px]
HPlat_crop_bottom = HPlat[slit_bottom_px]


## Find row index in EIT corresponding to these limits
y_px_crop_top = int(np.round(Y__HP_to_pixel(y_HP=HPlat_crop_top, header_eit=header_eit)))
y_px_crop_bottom = int(np.round(Y__HP_to_pixel(y_HP=HPlat_crop_bottom, header_eit=header_eit)))
x_px_crop_left = int(np.round(X__HP_to_pixel(x_HP=HPlon_rotcomp[0], header_eit=header_eit)))
x_px_crop_right = int(np.round(X__HP_to_pixel(x_HP=HPlon_rotcomp[-1], header_eit=header_eit)))


# Crop EIT array
data_eit_crop = data_eit[y_px_crop_top:y_px_crop_bottom, x_px_crop_left:x_px_crop_right]

# Corrected alignment
dx_px = 0
dy_px = -6
data_eit_crop_corrected = data_eit[y_px_crop_top+dy_px : y_px_crop_bottom+dy_px, x_px_crop_left+dx_px : x_px_crop_right+dx_px]


eit_extent = sumer_extent = [HPlon_rotcomp[0], HPlon_rotcomp[-1], HPlat_croplat[-1], HPlat_croplat[0]]


# Define extents properly for EACH image
extent_eit_px = [-0.5, data_eit_crop_corrected.shape[1]-0.5, data_eit_crop_corrected.shape[0]-0.5, -0.5]
extent_sumer_px = [-0.5, intensity_map_croplat.shape[1]-0.5, intensity_map_croplat.shape[0]-0.5, -0.5]


arr_sumer = intensity_map_croplat
arr_eit = data_eit_crop_corrected

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(9,8))
label_size = 18
ax[0].imshow(arr_eit, norm=LogNorm(vmin=vmin_eit, vmax=vmax_eit), cmap='Greys_r', extent=eit_extent)
ax[1].pcolormesh(HPlon_rotcomp, HPlat_croplat, arr_sumer, cmap='Greys_r', norm=LogNorm(vmin=vmin_sumer, vmax=vmax_sumer))
ax[1].axis('equal') # Ensures equal scaling of axis x and y
#ax[1].set_title(f'SUMER', fontsize=22)
#ax[0].set_title(f'EIT-{header_eit["WAVELNTH"]}', fontsize=22)
ax[1].set_xlabel('Helioprojective longitude (arcsec). Rot. compensated', fontsize=17)
fig.supylabel('Helioprojective latitude (arcsec)', fontsize=17)
ax[0].text(1.02, 0.5, f'EIT-{header_eit["WAVELNTH"]}', fontsize=22,transform=ax[0].transAxes, va='center', ha='left', rotation=90)
ax[1].text(1.02, 0.5, f'SUMER-{line_center_label}', fontsize=22,transform=ax[1].transAxes, va='center', ha='left', rotation=90)
plt.subplots_adjust(left=0.15, right=0.95, bottom=0.05, top=0.95, wspace=0, hspace=0)
ax[0].grid(color='white')
ax[1].grid(color='white')
ax[0].axvline(x=HPlon_rotcomp[closest_index], linestyle='-', linewidth=0.8, color='red', label='Slit position during\n EIT image')
ax[1].axvline(x=HPlon_rotcomp[closest_index], linestyle='-', linewidth=0.8, color='red', label='Slit position during\n EIT image')
plt.show(block=False)

# %%
header_sumer['CDELT2']
# Out:
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'SC_X0' is not FITS standard (invalid value string: '3.36618e-05 / Spacecraft pointing / solar X-axis').  Fixed 'SC_X0' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
#  [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'GEIX_OBS' is not FITS standard (invalid value string: '-1.11312e+09 / Geocentric equatorial inertial X').  Fixed 'GEIX_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'GEIY_OBS' is not FITS standard (invalid value string: '-1.07565e+09 / Geocentric equatorial inertial Y').  Fixed 'GEIY_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'GEIZ_OBS' is not FITS standard (invalid value string: '-6.11146e+08 / Geocentric equatorial inertial Z').  Fixed 'GEIZ_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'GSEX_OBS' is not FITS standard (invalid value string: '1.65578e+09 / Geocentric solar ecliptic X').  Fixed 'GSEX_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'GSEY_OBS' is not FITS standard (invalid value string: '1.01392e+08 / Geocentric solar ecliptic Y').  Fixed 'GSEY_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'GSEZ_OBS' is not FITS standard (invalid value string: '-1.32855e+08 / Geocentric solar ecliptic Z').  Fixed 'GSEZ_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'GSMX_OBS' is not FITS standard (invalid value string: '1.65578e+09 / Geocentric solar magnetic X').  Fixed 'GSMX_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'GSMY_OBS' is not FITS standard (invalid value string: '5.19567e+07 / Geocentric solar magnetic Y').  Fixed 'GSMY_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'GSMZ_OBS' is not FITS standard (invalid value string: '-1.58844e+08 / Geocentric solar magnetic Z').  Fixed 'GSMZ_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'HAEX_OBS' is not FITS standard (invalid value string: '1.04909e+11 / Heliocentric Aries Ecliptic X').  Fixed 'HAEX_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'HAEY_OBS' is not FITS standard (invalid value string: '1.02419e+11 / Heliocentric Aries Ecliptic Y').  Fixed 'HAEY_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'HAEZ_OBS' is not FITS standard (invalid value string: '-1.33578e+08 / Heliocentric Aries Ecliptic Z').  Fixed 'HAEZ_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'DSUN_OBS' is not FITS standard (invalid value string: '1.46614e+11 / Distance from Sun').  Fixed 'DSUN_OBS' card to meet the FITS standard. [astropy.io.fits.verify]
# SIMPLE  =                    T / Written by IDL:  Tue Sep 11 23:53:07 2018
# BITPIX  =                  -32 /  IEEE single precision floating point
# NAXIS   =                    2 / Number of data axes
# NAXIS1  =                  512 /
# NAXIS2  =                  360 /
# EXTEND  =                    T / FITS data may contain extensions
# DATE    = '2018-09-09'         /  Creation date of FITS header
# FILENAME= 'sum_19991107_05093080_15415_38.fits' / Name of the FITS file
# SORIG   = 'GenuineIntel GNU/Linux' / Architecture and OS
# DATASRC = 'Final Distribution (CDROM)' / Data Source
# TELESCOP= 'SOHO    '           /
# INSTRUME= 'SUMER   '           /
# DATE_MOD= '2018-09-11T21:53:07.110' / Last modified
# ORIGIN  = 'SOHO MPS'           / Where Data is Produced
# OBS_SEQ = 'Raster  '           / Name of observing sequence
# DATE_OBS= '1999-11-07T05:09:30.805' / Beginning of Observation Date (UTC)
# DATE_END= '1999-11-07T05:12:00.805' / End of Observation Date (UTC)
# OBT_TIME=       1320642602.805 / Starting time of acquisition (TAI)
# OBT_END =       1320642752.805 / End time of acquisition (TAI)
# LEVEL   = '1       '           / Data processing level
# PRODLVL = 'L1      '           / Data calibration level
# DETECTOR= 'A       '           / Detector used
# EXPTIME =               150.00 / Exposure time [s]
# IXWIDTH =              1.00000 / Image width ["]
# IYWIDTH =              300.000 / Image height ["]
# SLIT    = '<2> 1.0" * 300" centered' / SUMER slit
# INSTITUT= 'SUMER; TRACE (S/C); MDI; EIT; Kitt Peak (GBO)' / Name of institutes f
# CMP_TYPE= 'Campaign'           / Type of coordinated program
# LONGSTRN= 'OGIP 1.0'           / The OGIP long string convention may be used.
# COMMENT This FITS file may contain long string keyword values that are
# COMMENT continued over multiple keywords.  This convention uses the  '&'
# COMMENT character at the end of a string which is then continued
# COMMENT on subsequent keywords whose name = 'CONTINUE'.
# CMP_NAME= 'Chromosphere, Transition Region, and Coronal Transient Velocity Pro&'
# CONTINUE  'gram' / Name of campaign observation
# CMP_ID  =                 6223 / Campaign number
# STUDY_ID=                 2176 / Study number
# STUDY_NM= 'HAS EQCH3'          / Study name
# OBJECT  = 'CH      '           / Target
# SCI_OBJ = 'Coronal hole'       / The science objective
# SCI_SPEC= 'Eq.CH velocity map at 1541 HAS' / The specified objective
# POPUDP  =                    7 / POP/UDP number
# OBS_PROG= 'EQCH3.SCL'          / Name of scientist program
# SCIENTIS= '< 22> Donald Hassler' / Scientist responsible of POP/UDP
# FFONOFF = 'OFF     '           / On board flat field ON/OFF
# BINX    =                    1 / Binning X (1 - 1024)
# BINY    =                    1 / Binning Y (1 - 360)
# ROTCMP  =              0.00000 / Solar rotation compensation
# PIMGTYP = 'SINGLE  '           / Processing image Type (Single/Multiple)
# COMPRESS=                    5 / Compression method
# COMPAR1 =                   33 / Compression parameter 1
# COMPAR2 =                  176 / Compression parameter 2
# COMPAR3 =                    0 / Compression parameter 3
# DECOMP  =                    T / Decompression (F=No/T=Yes)
# ODEVCORR=                    T / Odd Even correction
# FLATCORR=                    T / Flatfield corrected on ground (F=No/T=Yes)
# FLATFILE= 'sumff_a_19990311_00020384_03.fits' / Used Flatfield Data
# FFMODDAT= '2016-10-26T06:33:55.217' / Creation/modification of Flatfield
# GEOMCORR=                    T / Geometry corrected on ground (F=No/T=Yes)
# DEADCORR=                    T / Dead time correction
# DCXDLEV =              9545.61 / Dead time corr XDL input value
# LGAINCOR=                    T / Local gain correction
# RADCORR =                    T / Radiometry calibration
# RADORDER=                    1 / Radiometry for Wavelength order
# AVARADO =                    2 / Available Radiometry orders
# WCSAXES =                    3 / Number of WCS axis
# CTYPE1  = 'WAVE    '           / Type of CRVAL1
# CUNIT1  = 'Angstrom'           / Axis unit along axis 1
# CRPIX1  =                  257 / Reference pixel along axis 1
# CRVAL1  =              1541.50 / Value at reference pixel of axis 1
# CDELT1  =            0.0422841 / Axis increments along axis 1
# CTYPE2  = 'HPLT-TAN'           / Type of CRVAL2
# CUNIT2  = 'arcsec  '           / Axis unit along axis 2
# CRPIX2  =              180.500 / Reference pixel along axis 2
# CRVAL2  =             -250.563 / Value at reference pixel of axis 2
# CDELT2  =                    1 / Axis increments along axis 2
# CTYPE3  = 'HPLN-TAN'           / Type of CRVAL3
# CUNIT3  = 'arcsec  '           / Axis unit along axis 3
# CRPIX3  =                    1 / Reference pixel along axis 3
# CRVAL3  =              342.595 / Value at reference pixel of axis 3
# CDELT3  =              1.00000 / Axis increments along axis 3 (Set to slit width
# IMGUNITS= 'W/sr/m^2/Angstroem' / Units for Image
# REFPIX  =                  530 / Original reference Pixel
# DETXSTRT=                  274 / Detector readout start / X
# DETXEND =                  785 / Detector readout end / X
# DETYSTRT=                    0 / Detector readout start / Y
# DETYEND =                  359 / Detector readout end / Y
# WAVEMIN =              1530.68 / Minimum wavelength in image
# WAVEMAX =              1552.32 / Maximum wavelength in image
# CORORB  =                    F / Orbitology corrected
# INS_X   =              343.188 / Pointing of instrument / instrument X-axis
# INS_Y   =             -249.750 / Pointing of instrument / instrument Y-axis
# SOLAR_X =              342.595 / Instrument pointing / solar X-axis
# SOLAR_Y =             -250.563 / Instrument pointing / solar Y-axis
# RASTYPE = 'RASTER  '           / Sequence type
# SC_X0   =          3.36618E-05 / Spacecraft pointing / solar X-axis
# SC_Y0   =            0.0142033 / Spacecraft pointing / solar Y-axis
# SC_ROLL =            -0.135791 / Spacecraft roll angle relative to the solar coo
# SOLAR_P0=        23.4232662936 / Solar angle P0 (degree)
# SOLAR_B0=        3.72422528267 / Solar angle B0 (degree)
# GEIX_OBS=         -1.11312E+09 / Geocentric equatorial inertial X
# GEIY_OBS=         -1.07565E+09 / Geocentric equatorial inertial Y
# GEIZ_OBS=         -6.11146E+08 / Geocentric equatorial inertial Z
# GSEX_OBS=          1.65578E+09 / Geocentric solar ecliptic X
# GSEY_OBS=          1.01392E+08 / Geocentric solar ecliptic Y
# GSEZ_OBS=         -1.32855E+08 / Geocentric solar ecliptic Z
# GSMX_OBS=          1.65578E+09 / Geocentric solar magnetic X
# GSMY_OBS=          5.19567E+07 / Geocentric solar magnetic Y
# GSMZ_OBS=         -1.58844E+08 / Geocentric solar magnetic Z
# HAEX_OBS=          1.04909E+11 / Heliocentric Aries Ecliptic X
# HAEY_OBS=          1.02419E+11 / Heliocentric Aries Ecliptic Y
# HAEZ_OBS=         -1.33578E+08 / Heliocentric Aries Ecliptic Z
# DSUN_OBS=          1.46614E+11 / Distance from Sun
# HGLN_OBS=           -0.0572959 / Stonyhurst heliographic longitude
# HGLT_OBS=              3.72423 / Stonyhurst heliographic latitude
# CRLN_OBS=              9.91217 / Carrington heliographic longitude
# CRLT_OBS=              3.72423 / Carrington heliographic latitude
# XCEN    =              342.595 / Center of the instrument FOV / solar X-axis
# YCEN    =             -250.563 / Center of the instrument FOV / solar Y-axis
# ANGLE   =            -0.135791 / Orientation of instrument FOV (degree)
# UDP_ID  =                 2744 / Reference to observing program
# PROG_NM = 'HAS EQCH3'          / Name of observing program
# T3TELE  =              52.8000 / Telescope (MC2) temperature (degree C)
# T3REAR  =              20.0000 / SUMER rear (MC3) temperature (degree C)
# T3FRONT =              20.0400 / SUMER front (MC4) temperature (degree C)
# T3SPACER=              23.1600 / SUMER spacer (MC6) temperature (degree C)
# MC2ENC  =                 2768 / SUMER MC2 Encoder Position
# MC3ENC  =                 1845 / SUMER MC3 Encoder Position
# MC4ENC  =                 1419 / SUMER MC4 Encoder Position
# MC6ENC  =                 3290 / SUMER MC6 Encoder Position
# MC8ENC  =               131072 / SUMER MC8 Encoder Position
# HKOTIME = '1999-11-07T05:10:49.390' / Time stamp of HK0 Record (UTC)
#
#         /SUMER Raw Image Header Entries
#
# SSYNC0  =                  235 / Header Sync Byte 0 (0xEB)
# SSYNC1  =                  144 / Header Sync Byte 1 (0x90)
# IMG_REC =                  128 / Header Record Id (0x80)
# SSTYPIMG=                   38 / SUMER image format index
# XSSTAI  =       1320642602.805 / Exposure start time (TAI)
# SSOPCNT =                   64 / Operations counter. 0 after switch on, increase
# SSPOPUDP=                    7 / POP/UDP number. 0 no POP/UDP executing
# SSIMGCNT=                  122 / Image counter, 0 at start of op +1 at spectrohe
# SSLOC   =                   22 / Scientist ID (after Jun 1996)
# SSTARGET=                  132 / Target as set by SYS_Operator
# SSFLDATE=                    0 / Never really used
# SSFLREQN=                    0 / Never really used
# SSREFPIX=                  530 / Reference pixel where lambda is on
# FREFPIX =                  530 / Ref pixel reduced by det B offset (2653)
# SSSTAT  =                   32 / Status
# SSEETRIG=                    0 / Explosive event trigger
# SSFF    =                    0 / Flatfield correction 1=on,0=off
# SSFF_T  = 'OFF     '           / Flatfield correction status as text
# SSDETTYP=                    1 / Current detector in use (1=A,2=B,3=RSC)
# SSDET_T = 'A       '           / Detector in use as text
# SSINTSTA=                    0 / IIF/TC spectrohelio interrupt status
# SSDETSTA=                  255 / Detector status
# SSSUNY  =                 5491 / SUMER coordinate Y [0.0625"]
# SSSUNZ  =                 3996 / SUMER coordinate Z [0.0625"]
# P_SUNY  =              343.188 / SUMER coordinate Y ["]
# P_SUNZ  =              249.750 / SUMER coordinate Z ["]
# SSEXPTIM=              150.000 / Exposure time [s]
# SSIIDZ  =                    0 / Inter instrument sun z coordinate
# SSIIDY  =                    0 / Inter instrument sun y coordinate
# SSBPADDY=                  509 / Brightest pix addr Y (spec dir 0..1023)
# SSBPADDZ=                  187 / Brightest pix addr Z (spat dir 0..359)
# SSIMGTOT=               928033 / Total counts in image
# SSROTCOM=              0.00000 / Rotation compensation time
# SSBPCNTS=                  176 / Brightest pixel counts
# SSACIMGC=                24534 / Accumulative image counter (0 after boot)
# SSSTEPN =                  240 / Number of raster steps (+ E->W, - W->E)
# SSSTEPSZ=                    8 / Raster step size in motor steps (neg=Schmiersch
# SSSLITN =                    2 / Number of slit selected
# SSBINNY =                    1 / Binning factor spectral dimension
# SSBINNZ =                    1 / Binning factor spatial direction
# SSXCNT  =                 1363 / X event count (raw value)
# SSYCNT  =                 1369 / Y event count (raw value)
# X_EVCNT =              9524.64 / X event count (corrected for detector)
# Y_EVCNT =              9566.57 / Y event count (corrected for detector)
# S_MCPV  =                  249 / High voltage raw value
# S_MCPVF =              5523.00 / High voltage [V]
# SIMCPI  =                  128 / MCP current (Raw value)
# SIMCPIF =              40.1280 / MCP current [uA]
# SSMC2POS=                 6742 / MC2-Azimuth position [0.38"]
# SSMC3POS=                 4518 / MC3-Elev position [0.38"]
# SSMC4POS=                 -954 / MC4-Slit select position [half step]
# SSMC6POS=                18048 / MC6-Grat position [half step]
# SSMC8POS=                 9504 / MC8-Scan mirror position [half step]
# SSMCERR =                    0 / Motor controller error
# SSCOMPRM=                    5 / Compression method
# SSWAVEL =              1541.50 / Wavelength at reference pixel (Angstroem)
# SSCOMPP1=                   33 / Compression parameter 1
# SSCOMPP2=                  176 / Compression parameter 2
# SSCOMPP3=                    0 / Compression parameter 3
# SSADMCNT=                 2744 / Admin cnt (gives the database udp id)
# XSSMDU  =                    0 / Missing data in image 0=no,1=yes
# XSSQAC  =                    0 / Quality of image data 0=OK,1=NOTOK
# XSSFID  =                    0 / File id from TM file catalog
# XSSFPTR =             22501680 / Pointer to image position in bin file
# XSCDID  =                 1275 / CD ID of TM file
# XSSEQID =                    1 / CD Sequence ID of TM file
# XSTMFILE=             93110101 / TM filename without ext
# PROCVERS=                  552 / SVN Version of write_sumerfits
#
#         / Data integrity check block
#
# CHECKSUM= '4B7C59694A6A4769'   / HDU checksum updated 2018-09-11T21:53:07
# DATASUM = '2419688181'         / data unit checksum updated 2018-09-11T21:53:07
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode 2001A&A...376..359H
# COMMENT The original raw image header is stored in the extention sumer-orig-raw-
# COMMENT The wavelength is stored low -> high
# COMMENT The data is stored with north up!
# COMMENT For documentation on SUMER FITS Data see:
# COMMENT Solar Physics June 2014, Volume 289, Issue 6, pp 2345???2376
# HISTORY Written with write_sumerfits Version:$Revision: 552 $
# HISTORY Applied decomp_method5 $Revision: 244 $
# HISTORY Applied update_fits $Revision: 561 $  9-Sep-2018 06:13:51.847
# HISTORY Applied DEADTIME_CORR Tue Sep 11 23:53:07 2018
# HISTORY Applied SUM_FLATFIELD with odd even corr Tue Sep 11 23:53:07 2018
# HISTORY Applied LOCAL_GAIN_CORR Tue Sep 11 23:53:07 2018
# HISTORY Applied SUM_FLATFIELD Tue Sep 11 23:53:07 2018
# HISTORY Applied DESTR_BILIN Tue Sep 11 23:53:07 2018
# HISTORY Applied RADIOMETRY Tue Sep 11 23:53:07 2018
# HISTORY Applied sumer_calib_fits Version:$Revision: 540 $
# HISTORY Calibration applied by SUMER

# %%
filename_eit_list = ['SOHO_EIT_171_19991107T010032_L1.fits', 'SOHO_EIT_195_19991107T042103_L1.fits', 'SOHO_EIT_284_19991107T011231_L1.fits', 'SOHO_EIT_304_19991107T013601_L1.fits', 'SOHO_EIT_171_19991107T070017_L1.fits', 'SOHO_EIT_195_19991107T063706_L1.fits', 'SOHO_EIT_284_19991107T070704_L1.fits', 'SOHO_EIT_304_19991107T073030_L1.fits']

for filename_eit_i in filename_eit_list:
    header_eit_i = fits.getheader(path_data_soho + 'eit/' + filename_eit_i) # Extract header
    label_eit_i = filename_eit_i[9:9+3] + '_' + filename_eit_i[21:21+7]
    print(label_eit_i+':', header_eit_i['CDELT1'], ',', header_eit_i['CDELT2'])
# Out:
# 171_T010032: 2.627 , 2.627
# 195_T042103: 5.254 , 5.254
# 284_T011231: 2.627 , 2.627
# 304_T013601: 2.627 , 2.627
# 171_T070017: 2.627 , 2.627
# 195_T063706: 5.254 , 5.254
# 284_T070704: 2.627 , 2.627
# 304_T073030: 2.627 , 2.627

# %%
px_as_EIT195 = 5.254 #[arcsec] 
px_as_EIT171 = 2.627 #[arcsec] 
px_as_SUMER = 1. #approx 1. is the slit width and the pixel scale along the slit
r_as = header_eit['RSUN_OBS'] #978.939298003 / [arcsec] apparent photospheric solar radius    
r_km = header_eit['RSUN_REF']/1000. #695699968 / [m] assumed physical solar radius  

#r_as  --> r_km
#px_as --> px_km??
px_km_EIT195 = px_as_EIT195 * r_km / r_as #km
px_km_EIT171 = px_as_EIT171 * r_km / r_as #km
px_km_SUMER = px_as_SUMER * r_km / r_as #km
#px_km_HRI = 237. #km

# %%
from matplotlib.patches import Rectangle

# side lengths
l1 = px_km_EIT195
l2 = px_km_EIT171
l3 = px_km_SUMER

fig, ax = plt.subplots(figsize=(9,9))
sq1 = Rectangle((0, 0), l1, l1, fill=False, edgecolor='blue', linewidth=2,  label=f"EIT 195 (binned 2x2): {int(np.round(l1))} km")
sq2 = Rectangle((0, 0), l2, l2, fill=False, edgecolor='green', linewidth=2, label=f"EIT 171, 284, 304: {int(np.round(l2))} km")
sq3 = Rectangle((0, 0), l3, l3, fill=False, edgecolor='red', linewidth=2,   label=f"SUMER: {int(np.round(l3))} km")
ax.add_patch(sq1)
ax.add_patch(sq2)
ax.add_patch(sq3)
l_max = np.max([l1,l2,l3])
dl_max = 0.1 * l_max
ax.set_xlim(-dl_max, dl_max+l_max)
ax.set_ylim(-dl_max, dl_max+l_max)
ax.set_aspect('equal')
ax.plot([0,100],[-0.04*l_max, -0.04*l_max], color='black', linewidth=1.5, label='100 and 1000 km')
ax.plot([0,1000],[-0.06*l_max, -0.06*l_max], color='black', linewidth=1.5)
ax.legend(loc="upper right")
plt.show()
